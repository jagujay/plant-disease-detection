# %% [markdown]
# # IMPORT STATEMENTS

# %%
import os
import json
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %% [markdown]
# # PATHS AND VARIABLES

# %%
TRAIN_DATA_DIR = "../data/combined-dataset-true/train"
TEST_DATA_DIR = "../data/combined-dataset-true/test"
train_dataset = datasets.ImageFolder(root=TRAIN_DATA_DIR)
test_dataset = datasets.ImageFolder(root=TEST_DATA_DIR)
sns.set_theme(style="whitegrid")

# %% [markdown]
# # TRAIN CLASSES AND COUNT

# %%
train_classes = train_dataset.classes
print(f"Total Classes: {len(train_classes)}")
print(f"Total Training Images: {len(train_dataset)}")
# Out:
# Total Classes: 31
# Total Training Images: 3438

# %%
train_class_counts = {class_name: 0 for class_name in train_classes}
for _, class_idx in train_dataset.samples:
    train_class_counts[train_classes[class_idx]] += 1

df_counts_train = pd.DataFrame(list(train_class_counts.items()), columns=['Disease Class', 'Image Count'])
df_counts_train = df_counts_train.sort_values(by='Image Count', ascending=False)
df_counts_train
# Out:
#                  Disease Class  Image Count
# 9             corn leaf blight          258
# 30   tomato septoria leaf spot          215
# 1              apple rust leaf          197
# 2              apple scab leaf          190
# 10              corn rust leaf          186
# 25     tomato leaf late blight          167
# 23  tomato leaf bacterial spot          163
# 24    tomato leaf early blight          159
# 29            tomato mold leaf          149
# 7          corn gray leaf spot          132
# 20  squash powdery mildew leaf          124
# 0                   apple leaf          113
# 18              raspberry leaf          112
# 15    potato leaf early blight          109
# 5               blueberry leaf          106
# 22                 tomato leaf          105
# 13                  peach leaf          103
# 16     potato leaf late blight           97
# 21             strawberry leaf           88
# 28    tomato leaf yellow virus           70
# 27  tomato leaf powdery mildew           62
# 8                    corn leaf           62
# 4        bell pepper leaf spot           62
# 11                  grape leaf           57
# 19               soyabean leaf           57
# 14          potato leaf blight           57
# 12        grape leaf black rot           56
# 3             bell pepper leaf           53
# 6                  cherry leaf           47
# 26    tomato leaf mosaic virus           44
# 17       potato leafroll virus           38

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='Image Count', y='Disease Class', data=df_counts_train, palette='viridis')
plt.title('Class Distribution in Combined Training Dataset', fontsize=16)
plt.xlabel('Number of Images', fontsize=12)
plt.ylabel('Class', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3564/1865179398.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Image Count', y='Disease Class', data=df_counts_train, palette='viridis')

# %% [markdown]
# # TEST CLASSES AND COUNT

# %%
test_classes = test_dataset.classes
print(f"Total Classes: {len(test_classes)}")
print(f"Total Testing Images: {len(test_dataset)}")
# Out:
# Total Classes: 31
# Total Testing Images: 434

# %%
test_class_counts = {class_name: 0 for class_name in test_classes}
for _, class_idx in test_dataset.samples:
    test_class_counts[test_classes[class_idx]] += 1

df_counts_test = pd.DataFrame(list(test_class_counts.items()), columns=['Disease Class', 'Image Count'])
df_counts_test = df_counts_test.sort_values(by='Image Count', ascending=False)
df_counts_test
# Out:
#                  Disease Class  Image Count
# 1              apple rust leaf           32
# 2              apple scab leaf           32
# 9             corn leaf blight           23
# 30   tomato septoria leaf spot           22
# 10              corn rust leaf           21
# 25     tomato leaf late blight           21
# 0                   apple leaf           20
# 24    tomato leaf early blight           20
# 23  tomato leaf bacterial spot           20
# 22                 tomato leaf           19
# 29            tomato mold leaf           17
# 7          corn gray leaf spot           15
# 11                  grape leaf           12
# 8                    corn leaf           11
# 14          potato leaf blight           11
# 27  tomato leaf powdery mildew           11
# 5               blueberry leaf           11
# 17       potato leafroll virus           11
# 26    tomato leaf mosaic virus           10
# 6                  cherry leaf           10
# 13                  peach leaf            9
# 4        bell pepper leaf spot            9
# 3             bell pepper leaf            8
# 12        grape leaf black rot            8
# 16     potato leaf late blight            8
# 15    potato leaf early blight            8
# 21             strawberry leaf            8
# 19               soyabean leaf            8
# 18              raspberry leaf            7
# 20  squash powdery mildew leaf            6
# 28    tomato leaf yellow virus            6

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='Image Count', y='Disease Class', data=df_counts_test, palette='viridis')
plt.title('Class Distribution in Combined Testing Dataset', fontsize=16)
plt.xlabel('Number of Images', fontsize=12)
plt.ylabel('Class', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3564/757096600.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Image Count', y='Disease Class', data=df_counts_test, palette='viridis')

# %% [markdown]
# # CALCULATE STANDARD INVERSE CLASS WEIGHTS

# %%
# Formula: total_samples / (num_classes * count_for_class)
total_samples = len(train_dataset)
num_classes = len(train_classes)

weights = []
for class_name in train_classes:
    count = train_class_counts[class_name]
    weight = total_samples / (num_classes * count)
    weights.append(weight)

# %%
class_weights_tensor = torch.FloatTensor(weights)
weight_dict = {class_name: float(weight) for class_name, weight in zip(train_classes, weights)}
print(f"class_weights = {weight_dict}")
# Out:
# class_weights = {'apple leaf': 0.9814444761632886, 'apple rust leaf': 0.5629605370885868, 'apple scab leaf': 0.5837011884550085, 'bell pepper leaf': 2.0925136944613514, 'bell pepper leaf spot': 1.7887617065556711, 'blueberry leaf': 1.0462568472306757, 'cherry leaf': 2.359643102264928, 'corn gray leaf spot': 0.8401759530791789, 'corn leaf': 1.7887617065556711, 'corn leaf blight': 0.4298574643660915, 'corn rust leaf': 0.5962539021852237, 'grape leaf': 1.9456706281833616, 'grape leaf black rot': 1.9804147465437787, 'peach leaf': 1.0767303476354526, 'potato leaf blight': 1.9456706281833616, 'potato leaf early blight': 1.0174607872151524, 'potato leaf late blight': 1.1433322248087796, 'potato leafroll virus': 2.9185059422750426, 'raspberry leaf': 0.9902073732718893, 'soyabean leaf': 1.9456706281833616, 'squash powdery mildew leaf': 0.8943808532778356, 'strawberry leaf': 1.2602639296187683, 'tomato leaf': 1.056221198156682, 'tomato leaf bacterial spot': 0.6803878883831387, 'tomato leaf early blight': 0.6975045648204504, 'tomato leaf late blight': 0.6640911724937222, 'tomato leaf mosaic virus': 2.5205278592375366, 'tomato leaf powdery mildew': 1.7887617065556711, 'tomato leaf yellow virus': 1.584331797235023, 'tomato mold leaf': 0.7443169517211518, 'tomato septoria leaf spot': 0.5158289572393099}

# %%
weights_path = Path(TRAIN_DATA_DIR).parent / "class_weights.json"
with open(weights_path, 'w') as f:
    json.dump(weight_dict, f, indent=4)
print(f"Weights successfully saved to: {weights_path}")
# Out:
# Weights successfully saved to: ../data/combined-dataset-true/class_weights.json

# %% [markdown]
# # GAUSSIAN NOISE

# %%
class AddGaussianNoise(object):
    def __init__(self, mean=0., std=0.05):
        self.std = std
        self.mean = mean
        
    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean

# %% [markdown]
# # DEFINE TRANSFORMS

# %%
clean_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

noisy_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    AddGaussianNoise(mean=0.0, std=0.05)
])

# %% [markdown]
# # TRAIN IMAGE

# %%
sample_path_train = train_dataset.samples[0][0]
train_img = Image.open(sample_path_train).convert('RGB')

# %%
clean_img_train = clean_transform(train_img).permute(1, 2, 0).numpy()
noisy_img_train = noisy_transform(train_img).permute(1, 2, 0).numpy()
noisy_img_train = np.clip(noisy_img_train, 0, 1)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(clean_img_train)
axes[0].set_title("Original (Resized)")
axes[0].axis('off')

axes[1].imshow(noisy_img_train)
axes[1].set_title("With Gaussian Noise (\u03BC=0, \u03C3=0.05)")
axes[1].axis('off')

plt.show()

# %% [markdown]
# # TEST IMAGE

# %%
sample_path_test = test_dataset.samples[0][0]
test_img = Image.open(sample_path_test).convert('RGB')

# %%
clean_img_test = clean_transform(test_img).permute(1, 2, 0).numpy()
noisy_img_test = noisy_transform(test_img).permute(1, 2, 0).numpy()
noisy_img_test = np.clip(noisy_img_test, 0, 1)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(clean_img_test)
axes[0].set_title("Original (Resized)")
axes[0].axis('off')

axes[1].imshow(noisy_img_test)
axes[1].set_title("With Gaussian Noise (\u03BC=0, \u03C3=0.05)")
axes[1].axis('off')

plt.show()
